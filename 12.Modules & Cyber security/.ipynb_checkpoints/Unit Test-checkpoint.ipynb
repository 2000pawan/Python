# %%
import unittest

# %%
def prime(x):
    for i in range(2,x-1):
        if x%i==0:
            print('Given Number',x,'is not Prime!')
        else:
            print('Given Number',x,'is Prime!')
x=int(input('Enter a number you want to check for prime or not!:-'))
prime(x)
# Out:
# Enter a number you want to check for prime or not!:- 9
# Given Number 9 is Prime!
# Given Number 9 is not Prime!
# Given Number 9 is Prime!
# Given Number 9 is Prime!
# Given Number 9 is Prime!
# Given Number 9 is Prime!

# %%
for i in range(5):
    print(i)
    print('pawan')
# Out:
# 0
# pawan
# 1
# pawan
# 2
# pawan
# 3
# pawan
# 4
# pawan
