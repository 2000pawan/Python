# %%
n,p,q=9,3,1
for i in range(1,6):
    print(n,end='')
    for j in range(1,6):
        if i<=2 and j<=3 or i<=3 and j<=2 or i==4 and j<=1:
            print(p,end='')
            p=p+2
        elif i==1 and j==5:
            print(q,end='')
    else:
        print('')
    p=3
# Out:
# 93571
# 9357
# 935
# 93
# 9

# %%
for i in range(1,11):
    for j in range(1,11):
        if j<=i:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
for i in range(5):
    for j in range(5):
        if j>=i:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
for i in range(1,6):
    for j in range(1,6):
        if j<=6-i:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(1,6):
    for j in range(1,10):
        if j>=6-i and j<=4+i:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
p=1
for i in range(1,6):
    for j in range(1,10):
        if j>=6-i and j<=4+i:
            print(p,end='')
            p+=1
        else:
            print(' ',end='')
    print()
    p=1
# Out:
#     1
#    123
#   12345
#  1234567
# 123456789

# %%
for i in range(1,6):
    for j in range(1,6):
        if j<=i:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,6):
    for j in range(1,6):
        if j>=6-i:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
for i in range(1,6):
    for j in range(1,6):
        if j>=6-i and j<=4+i:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
for i in range(1,6):
    for j in range(10):
        if j>=6-i and j<=4+i:
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
for i in range(1,6):
    for j in range(10):
        if (i==3 and j==3 ):
            print('*',end='')
        else:
            print(' ',end='')
    print()
# Out:
#
#
#    *
